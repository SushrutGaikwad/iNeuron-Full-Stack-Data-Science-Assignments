# %% [markdown]
# # Assignment 7
#
# ***Name: Sushrut Gaikwad***

# %% [markdown]
# ## Question 1
# **What is the name of the feature responsible for generating `Regex` objects?**

# %% [markdown]
# **Answer:**
#
# `re.compile()`.

# %% [markdown]
# ## Question 2
# **Why do raw strings often appear in `Regex` objects?**

# %% [markdown]
# **Answer:**
#
# Raw strings are used to not have backslashes escaped.

# %% [markdown]
# ## Question 3
# **What is the return value of the `search()` method?**

# %% [markdown]
# **Answer:**
#
# It is `Match` objects.

# %% [markdown]
# ## Question 4
# **From a `Match` item, how do you get the actual strings that match the pattern?**

# %% [markdown]
# **Answer:**
#
# We use the `group()` function.

# %% [markdown]
# ## Question 5
# **In the regex which created from the `r'(\d\d\d)-(\d\d\d-\d\d\d\d)'`, what does group zero cover? Group `2`? Group `1`?**

# %% [markdown]
# **Answer:**
#
# Group zero is the complete match, group `1` is in the first set of brackets, and group `2` is in the second set of brackets.

# %% [markdown]
# ## Question 6
# **In standard expression syntax, parentheses and intervals have distinct meanings. How can you tell a regex that you want it to fit real parentheses and periods?**

# %% [markdown]
# **Answer:**
#
# Periods are escaped using `\.`, and parenthesis are escaped using `\(`, `\)`.

# %% [markdown]
# ## Question 7
# **The `findall()` method returns a string list or a list of string tuples. What causes it to return one of the two options?**

# %% [markdown]
# **Answer:**
#
# When regex has no groups we get a strings list. When regex has groups we get a list of string tuples.

# %% [markdown]
# ## Question 8
# **In standard expressions, what does the `|` character mean?**

# %% [markdown]
# **Answer:**
#
# `|` means matching "either, or" between two groups.

# %% [markdown]
# ## Question 9
# **In regular expressions, what does the character `?` stand for?**

# %% [markdown]
# **Answer:**
#
# `?` stands for either "match zero or one of the preceding group", or can be used to show nongreedy matching.

# %% [markdown]
# ## Question 10
# **In regular expressions, what is the difference between the `+` and `*` characters?**

# %% [markdown]
# **Answer:**
#
# `+` matches one or more, whereas `*` matches zero or more.

# %% [markdown]
# ## Question 11
# **What is the difference between `{4}` and `{4,5}` in regular expression?**

# %% [markdown]
# **Answer:**
#
# `{4}` matches exactly four instances of the preceding group.`{4,5}` matches between four and five instances.

# %% [markdown]
# ## Question 12
# **What do you mean by the `\d`, `\w`, and `\s` shorthand character classes signify in regular expressions?**

# %% [markdown]
# **Answer:**
#
# They match a single digit, word, and space character respectively.

# %% [markdown]
# ## Question 13
# **What do means by `\D`, `\W`, and `\S` shorthand character classes signify in regular expressions?**

# %% [markdown]
# **Answer:**
#
# They match a single character that is not a digit, not a word, and not a space respectively.

# %% [markdown]
# ## Question 14
# **What is the difference between `.*` and `.*?`?**

# %% [markdown]
# **Answer:**
#
# `.*` performs a greedy match, whereas `.*?` performs a nongreedy match.

# %% [markdown]
# ## Question 15
# **What is the syntax for matching both numbers and lowercase letters with a character class?**

# %% [markdown]
# **Answer:**
#
# `[0-9a-z]` or `[a-z0-9]`.

# %% [markdown]
# ## Question 16
# **What is the procedure for making a normal expression in regax case insensitive?**

# %% [markdown]
# **Answer:**
#
# Pass `re.I` or `re.IGNORECASE` to `re.compile()`.

# %% [markdown]
# ## Question 17
# **What does the `.` character normally match? What does it match if `re.DOTALL` is passed as 2nd argument in `re.compile()`?**

# %% [markdown]
# **Answer:**
#
# `.` character matches any character except the newline character. Passing `re.DOTALL` to `re.compile()` would make it also match the newline character.

# %% [markdown]
# ## Question 18
# **If `numReg = re.compile(r'\d+')`, what will `numRegex.sub('X', '11 drummers, 10 pipers, five rings, 4 hen')` return?**

# %% [markdown]
# **Answer:**
#
# `'X drummers, X pipers, five rings, X hens'`

# %% [markdown]
# ## Question 19
# **What does passing `re.VERBOSE` as the 2nd argument to `re.compile()` allow to do?**

# %% [markdown]
# **Answer:**
#
# It allows us to add whitespace and comments to the string passed to `re.compile()`.

# %% [markdown]
# ## Question 20
# **How would you write a regex that match a number with comma for every three digits? It must match the given following:**
# * `'42'`
# * `'1,234'`
# * `'6,368,745'`
#
# **but not the following:**
# * `'12,34,567'` (which has only two digits between the commas)
# * `'1234'` (which lacks commas)

# %% [markdown]
# **Answer:**
#
# `re.compile(r'^\d{1,3}(,\d{3})*$')`

# %% [markdown]
# ## Question 21
# **How would you write a regex that matches the full name of someone whose last name is Watanabe? You can assume that the first name that comes before it will always be one word that begins with a capital letter. The regex must match the following:**
# * `'Haruto Watanabe'`
# * `'Alice Watanabe'`
# * `'RoboCop Watanabe'`
#
# **but not the following:**
# * `'haruto Watanabe'` (where the first name is not capitalized)
# * `'Mr. Watanabe'` (where the preceding word has a nonletter character)
# * `'Watanabe'` (which has no first name)
# * `'Haruto watanabe'` (where Watanabe is not capitalized)

# %% [markdown]
# **Answer:**
#
# `re.compile(r'[A-Z][a-z]*\sWatanabe')`

# %% [markdown]
# ## Question 22
# **How would you write a regex that matches a sentence where the first word is either *Alice*, *Bob*, or *Carol*; the second word is either *eats*, *pets*, or *throws*; the third word is *apples*, *cats*, or *baseballs*; and the sentence ends with a period? This regex should be case-insensitive. It must match the following:**
# * `'Alice eats apples.'`
# * `'Bob pets cats.'`
# * `'Carol throws baseballs.'`
# * `'Alice throws Apples.'`
# * `'BOB EATS CATS.'`
#
# **but not the following:**
# * `'RoboCop eats apples.'`
# * `'ALICE THROWS FOOTBALLS.'`
# * `'Carol eats 7 cats.'`

# %% [markdown]
# **Answer:**
#
# `re.compile(r'(Alice|Bob|Carol)\s(eats|pets|throws)\s(apples|cats|baseballs)\.', re.IGNORECASE)`
