# %% [markdown]
# # Assignment 3
# ***Name: Sushrut Gaikwad***

# %% [markdown]
# ## Question 1
# **Why are functions advantageous to have in a program?**

# %% [markdown]
# **Answer:**
#
# Functions are advantageous because they allow us to reuse the same code.

# %% [markdown]
# ## Question 2
# **When does the code in a function run; when it is specified or when it is called?**

# %% [markdown]
# **Answer:**
#
# The code in a function runs when it is called.

# %% [markdown]
# ## Question 3
# **What statement creates a function?**

# %% [markdown]
# **Answer:**
#
# The `def` keyword is used to create a function.

# %% [markdown]
# ## Question 4
# **What is the difference between a function and a function call?**

# %% [markdown]
# **Answer:**
#
# A function is a block of code inside the `def` keyword which is reusable, whereas a function call is used to execute the function whenever required.

# %% [markdown]
# ## Question 5
# **How many global and local scopes are there in a Python program?**

# %% [markdown]
# **Answer:**
#
# There is a global scope which is created when we define a variable outside the function, and when we define a variable in a function, it has a local scope.

# %% [markdown]
# ## Question 6
# **What happens to variables in a local scope when the function call returns?**

# %% [markdown]
# **Answer:**
#
# When the function is called, the variables in local scope of the function are destroyed.

# %% [markdown]
# ## Question 7
# **What is the concept of a return value? Is it possible to have a return value in an expression?**

# %% [markdown]
# **Answer:**
#
# The return value of a function is the value calculated by the function. We can use this returned value in an expression, or we can store this returned value in a variable to use it later.

# %% [markdown]
# ## Question 8
# **If a function does not have a return statement, what is the return value of the call to that function?**

# %% [markdown]
# **Answer:**
#
# If there is no return value in the function, then the call of that function returns `None`. It returns an object of type `NoneType`, as is shown in the following example.

# %%
def func():
    return

func(), type(func())
# Out:
# (None, NoneType)

# %% [markdown]
# ## Question 9
# **How do you make a function variable refer to the global variable?**

# %% [markdown]
# **Answer:**
#
# To make a global variable inside a function, we use the `global` keyword for the variable.

# %% [markdown]
# ## Question 10
# **What is the datatype of `None`?**

# %% [markdown]
# **Answer:**
#
# The datatype of `None` is `NoneType`, as can be seen in the example illustrated in question 8.

# %% [markdown]
# ## Question 11
# **What does the following sentence do?**
# ```
# import areallyourpetsnamederic
# ```

# %% [markdown]
# **Answer:**
#
# That import statement imports a module named `areallyourpetsnamederic`.

# %% [markdown]
# ## Question 12
# **If you had a `bacon()` feature in a `spam` module, what would you call it after importing `spam`?**

# %% [markdown]
# **Answer:**
#
# It would be called with `spam.bacon()`.

# %% [markdown]
# ## Question 13
# **What can you do to save a program from crashing if it encounters an error?**

# %% [markdown]
# **Answer:**
#
# We can use the `try` clause on the program and use the `except` clause to handle the error.

# %% [markdown]
# ## Question 14
# **What is the purpose of `try` and the `except` clause?**

# %% [markdown]
# **Answer:**
#
# We put the suspicious code inside the `try` clause, and if an error occurs we can write the code we want to execute in the `except` clause.
