# %% [markdown]
# # Assignment 8
#
# ***Name: Sushrut Gaikwad***

# %% [markdown]
# ## Question 1
# **Is the Python Standard Library included with PyInputPlus?**

# %% [markdown]
# **Answer:**
#
# PyInputPlus is not included in the python standard library.

# %% [markdown]
# ## Question 2
# **Why is PyInputPlus commonly imported with `import pyinputplus as pypi`?**

# %% [markdown]
# **Answer:**
#
# Because `pypi` is easier to type as compared to `pyinputplus`.

# %% [markdown]
# ## Question 3
# **How do you distinguish between `inputInt()` and `inputFloat()`?**

# %% [markdown]
# **Answer:**
#
# `inputInt()` returns an integer value, whereas `inputFloat()` returns a floating point number.

# %% [markdown]
# ## Question 4
# **Using PyInputPlus, how do you ensure that the user enters a whole number between `0` and `99`?**

# %% [markdown]
# **Answer:**
#
# `pyip.inputint(min=0, max=99)`

# %% [markdown]
# ## Question 5
# **What is transferred to the keyword arguments `allowRegexes` and `blockRegexes`?**

# %% [markdown]
# **Answer:**
#
# A list of regex strings that are either explicitly allowed or denied.

# %% [markdown]
# ## Question 6
# **If a blank input is entered three times, what does `inputStr(limit=3)` do?**

# %% [markdown]
# **Answer:**
#
# `RetryLimitException`

# %% [markdown]
# ## Question 7
# **If blank input is entered three times, what does `inputStr(limit=3, default='hello')` do?**

# %% [markdown]
# **Answer:**
#
# It returns `hello`.
