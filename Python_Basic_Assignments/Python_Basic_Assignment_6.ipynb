# %% [markdown]
# # Assignment 6
#
# ***Name: Sushrut Gaikwad***

# %% [markdown]
# ## Question 1
# **What are escape characters, and how do you use them?**

# %% [markdown]
# **Answer:**
#
# Escape characters represent characters in string values that would otherwise be difficult or impossible to type into code.

# %% [markdown]
# ## Question 2
# **What do the escape characters `\n` and `\t` stand for?**

# %% [markdown]
# **Answer:**
#
# `\n` means a new line, whereas `\t` means a tab.

# %% [markdown]
# ## Question 3
# **What is the way to include backslash characters in a string?**

# %% [markdown]
# **Answer:**
#
# The `\\` escape character will represent a backslash character.

# %% [markdown]
# ## Question 4
# **The string `"Howl's Moving Castle"` is a correct value. Why isn't the single quote character in the word `Howl's` not escaped a problem?**

# %% [markdown]
# **Answer:**
#
# This is because we are using double quotes for the entire string.

# %% [markdown]
# ## Question 5
# **How do you write a string of newlines if you don't want to use the `\n` character?**

# %% [markdown]
# **Answer:**
#
# We can use multiline strings which are enclosed in triple quotes.

# %% [markdown]
# ## Question 6
# **What are the values of the given expressions?**
# ```
# 'Hello, world!'[1]
# ```
# ```
# 'Hello, world!'[0:5]
# ```
# ```
# 'Hello, world!'[:5]
# ```
# ```
# 'Hello, world!'[3:]
# ```

# %% [markdown]
# **Answer:**
#
# Let's code and see.

# %%
'Hello, world!'[1]
# Out:
# 'e'

# %%
'Hello, world!'[0:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[3:]
# Out:
# 'lo, world!'

# %% [markdown]
# ## Question 7
# **What are the values of the following expressions?**
# ```
# 'Hello'.upper()
# ```
# ```
# 'Hello'.upper().isupper()
# ```
# ```
# 'Hello'.upper().lower()
# ```

# %% [markdown]
# **Answer:**
#
# Let's code and see.

# %%
'Hello'.upper()
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper()
# Out:
# True

# %%
'Hello'.upper().lower()
# Out:
# 'hello'

# %% [markdown]
# ## Question 8
# **What are the values of the following expressions?**
# ```
# 'Remember, remember, the fifth of July.'.split()
# ```
# ```
# '-'.join('There can only one'.split())
# ```

# %% [markdown]
# **Answer:**
#
# Let's code and see.

# %%
'Remember, remember, the fifth of July.'.split()
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']

# %%
'-'.join('There can only one'.split())
# Out:
# 'There-can-only-one'

# %% [markdown]
# ## Question 9
# **What are the methods for right-justifying, left-justifying, and centering a string?**

# %% [markdown]
# **Answer:**
#
# `rjust()`, `ljust()`, and `center()`.

# %% [markdown]
# ## Question 10
# **What is the best way to remove whitespace characters from the start or end?**

# %% [markdown]
# **Answer:**
#
# `lstrip()` removes whitespaces from the left of the string, whereas `rstrip()` removes whitespaces from the right of the string.
