# %% [markdown]
# # Assignment 4
#
# ***Name: Sushrut Gaikwad***

# %% [markdown]
# ## Question 1
# **What exactly is `[]`?**

# %% [markdown]
# **Answer:**
#
# `[]` denotes an empty list.

# %% [markdown]
# ## Question 2
# **In a list of values stored in a variable called `spam`, how would you assign the value `'hello'`; as the
# third value? (Assume `[2, 4, 6, 8, 10]` are in `spam`.)**

# %% [markdown]
# **Answer:**
#
# I would do the following:

# %%
spam = [2, 4, 6, 8, 10]

spam[2] = 'hello'

spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# ## Let's pretend that `spam` includes the list `['a', 'b', 'c', 'd']` for the next three questions.

# %% [markdown]
# ## Question 3
# **What is the value of `spam[int(int('3'*2)/11)]`?**

# %% [markdown]
# **Answer:**
#
# Let's code this.

# %%
spam = ['a', 'b', 'c', 'd']

spam[int(int('3'*2)/11)]
# Out:
# 'd'

# %% [markdown]
# **Explanation:** `'3'*2` gives `'33'` which is converted to `int`, and is divided by `11`, which eventually gives `spam[3]`.

# %% [markdown]
# ## Question 4
# **What is the value of `spam[-1]`?**

# %% [markdown]
# **Answer:**
#
# Let's again code this.

# %%
spam[-1] # This should give the last element, i.e., `d`
# Out:
# 'd'

# %% [markdown]
# ## Question 5
# **What is the value of `spam[:2]`?**

# %% [markdown]
# **Answer:**
#
# Let's code this.

# %%
spam[:2] # This should give the first two elements
# Out:
# ['a', 'b']

# %% [markdown]
# ## Let's pretend that `bacon` has the list `[3.14, 'cat', 11, 'cat', 'True']` for the next three questions.

# %% [markdown]
# ## Question 6
# **What is the value of `bacon.index['cat']`?**

# %% [markdown]
# **Answer:**
#
# Let's code this.

# %%
bacon = [3.14, 'cat', 11, 'cat', 'True']

# %%
bacon.index('cat') # This should return the index of the first occurence of `cat` which is `1`
# Out:
# 1

# %% [markdown]
# ## Question 7
# **How does `bacon.append(99)` change the look of the list in `bacon`?**

# %% [markdown]
# **Answer:**
#
# Let's code this.

# %%
bacon.append(99) # This should append the integer `99` at the end of `bacon`
bacon
# Out:
# [3.14, 'cat', 11, 'cat', 'True', 99]

# %% [markdown]
# ## Question 8
# **How does `bacon.remove('cat')` change the look of the list in `bacon`?**

# %% [markdown]
# **Answer:**
#
# Let's code this.

# %%
bacon.remove('cat') # This should remove the first occurence of `cat` from the `bacon` list
bacon
# Out:
# [3.14, 11, 'cat', 'True', 99]

# %% [markdown]
# ## Question 9
# **What are the list concatenation and list replication operators?**

# %% [markdown]
# **Answer:**
#
# List concatenation is done using the `+` operator, whereas list replication is done using the `*` operator.

# %% [markdown]
# ## Question 10
# **What is difference between the list methods `append()` and `insert()`?**

# %% [markdown]
# **Answer:**
#
# `append()` adds elements to a list at the end, whereas `insert()` can add elements anywhere in the list.

# %% [markdown]
# ## Question 11
# **What are the two methods for removing items from a list?**

# %% [markdown]
# **Answer:**
#
# The `del` statement and the `remove()` method.

# %% [markdown]
# ## Question 12
# **Describe how list values and string values are identical.**

# %% [markdown]
# **Answer:**
#
# Both lists and strings can be passed to `len()`, have indexes and slices, be used in `for` loops, be concatenated or replicated, and be used with the `in` and `not in` operators.

# %% [markdown]
# ## Question 13
# **What&#39;s the difference between tuples and lists?**

# %% [markdown]
# **Answer:**
#
# Lists are mutable, whereas tuples are not. Lists are written using square brackets, i.e., inside `[` and `]`, whereas tuples are written using parenthesis, i.e., inside `(` and `)`.

# %% [markdown]
# ## Question 14
# **How do you type a tuple value that only contains the integer 42?**

# %% [markdown]
# **Answer:**
#
# In the following way.

# %%
(42,)
# Out:
# (42,)

# %% [markdown]
# ## Question 15
# **How do you get a list value's tuple form? How do you get a tuple value's list form?**

# %% [markdown]
# **Answer:**
#
# To get a list value's tuple form, we use `tuple()`, whereas for a tuple value's list form we use `list()`.

# %% [markdown]
# ## Question 16
# **Variables that "contain" list values are not necessarily lists themselves. Instead, what do they
# contain?**

# %% [markdown]
# **Answer:**
#
# They contain references to list values.

# %% [markdown]
# ## Question 17
# **How do you distinguish between `copy.copy()` and `copy.deepcopy()`?**

# %% [markdown]
# **Answer:**
#
# The `copy.copy()` function will do a shallow copy of a list, while the `copy.deepcopy()` function will do a deep copy of a list. That is, only `copy.deepcopy()` will duplicate any lists inside the list.
