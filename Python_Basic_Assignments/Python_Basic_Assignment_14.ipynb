# %% [markdown]
# # Assignment 14
#
# ***Name: Sushrut Gaikwad***

# %% [markdown]
# ## Question 1
# **What does RGBA stand for?**

# %% [markdown]
# **Answer:**
#
# Red, green, blue, and alpha.

# %% [markdown]
# ## Question 2
# **From the `Pillow` module, how do you get the RGBA value of any images?**

# %% [markdown]
# **Answer:**
#
# `ImageColor.getcolor(f'{image_name}', 'RGBA')`

# %% [markdown]
# ## Question 3
# **What is a box tuple, and how does it work?**

# %% [markdown]
# **Answer:**
#
# A box tuple is a tuple value of four values. First is the x-coordinate of the left edge, second is the y-coordinate of the top edge, third is the width, and fourth is the height.

# %% [markdown]
# ## Question 4
# **Use your image and load in notebook then, how can you find out the width and height of an
# Image object?**

# %% [markdown]
# **Answer:**

# %%
from PIL import Image
puppy_im = Image.open('Assignment_14_image/puppy.png')
puppy_im.size
# Out:
# (564, 564)

# %% [markdown]
# This is (width, height).

# %% [markdown]
# ## Question 5
# **What method would you call to get `Image` object for a 100×100 image, excluding the lower-left
# quarter of it?**

# %% [markdown]
# **Answer:**
#
# We would use `imageObj.crop((0, 50, 50, 50))`.

# %% [markdown]
# ## Question 6
# **After making changes to an `Image` object, how could you save it as an image file?**

# %% [markdown]
# **Answer:**
#
# We will use `imageObj.save(f'{image_name}.png')`.

# %% [markdown]
# ## Question 7
# **What module contains Pillow’s shape-drawing code?**

# %% [markdown]
# **Answer:**
#
# `ImageDraw`

# %% [markdown]
# ## Question 8
# **`Image` objects do not have drawing methods. What kind of object does? How do you get this kind
# of object?**

# %% [markdown]
# **Answer:**
#
# `ImageDraw` object does have drawing methods. We get these methods by passing the `Image` object to `ImageDraw.Draw()`.
