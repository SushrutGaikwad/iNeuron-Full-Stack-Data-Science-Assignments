# %% [markdown]
# # Assignment 11
#
# ***Name: Sushrut Gaikwad***

# %% [markdown]
# ## Question 1
# **Create an `assert` statement that throws an `AssertionError` if the variable `spam` is a negative integer.**

# %% [markdown]
# **Answer:**

# %%
spam = -5

assert spam>=0, "`spam` is a negative integer"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15096/582420020.py in <module>
#       1 spam = -5
#       2
# ----> 3 assert spam>=0, "`spam` is a negative integer"
#
# AssertionError: `spam` is a negative integer

# %% [markdown]
# ## Question 2
# **Write an `assert` statement that triggers an `AssertionError` if the variables `eggs` and `bacon` contain strings that are the same as each other, even if their cases are different (that is, `'hello'` and `'hello'` are considered the same, and `'goodbye'` and `'GOODbye'` are also considered the same).**

# %% [markdown]
# **Answer:**

# %%
eggs = 'goodbye'
bacon = 'GOODbye'

assert eggs.lower() != bacon.lower(), "The variables `eggs` and `bacon` are the same"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15096/3477463813.py in <module>
#       2 bacon = 'GOODbye'
#       3
# ----> 4 assert eggs.lower() != bacon.lower(), "The variables `eggs` and `bacon` are the same"
#
# AssertionError: The variables `eggs` and `bacon` are the same

# %% [markdown]
# ## Question 3
# **Create an `assert` statement that throws an `AssertionError` every time.**

# %% [markdown]
# **Answer:**

# %%
assert False, "This always throws an `AssertionError`"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15096/398919410.py in <module>
# ----> 1 assert False, "This always throws an `AssertionError`"
#
# AssertionError: This always throws an `AssertionError`

# %% [markdown]
# ## Question 4
# **What are the two lines that must be present in your software in order to call `logging.debug()`?**

# %% [markdown]
# **Answer:**

# %% [markdown]
# ```
# import logging
# logging.basicConfig(level=logging.DEBUG)
# ```

# %% [markdown]
# ## Question 5
# **What are the two lines that your program must have in order to have `logging.debug()` send a logging message to a file named *programLog.txt*?**

# %% [markdown]
# ```
# import logging
# logging.basicConfig(filename='programLog.txt', level=logging.DEBUG)
# ```

# %% [markdown]
# ## Question 6
# **What are the five levels of logging?**

# %% [markdown]
# **Answer:**
#
# The five levels are DEBUG, INFO, WARNING, ERROR, and CRITICAL.

# %% [markdown]
# ## Question 7
# **What line of code would you add to your software to disable all logging messages?**

# %% [markdown]
# **Answer:**
#
# `logging.disable(logging.CRITICAL)`

# %% [markdown]
# ## Question 8
# **Why is using logging messages better than using `print()` to display the same message?**

# %% [markdown]
# **Answer:**
#
# Logging offers much more flexibility. It proves to be of great benifit if we want to go back and investigate where the code gave an error. It offers a much better way to document our code in multiple files, etc.

# %% [markdown]
# ## Question 9
# **What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?**

# %% [markdown]
# **Answer:**
#
# The Step In button moves the debugger into a function call. The Step Over button quickly executes the function call without stepping into it. The Step Out button quickly executes the rest of the code until it steps out of the function it currently is in.

# %% [markdown]
# ## Question 10
# **After you click Continue, when will the debugger stop?**

# %% [markdown]
# **Answer:**
#
# After clicking Continue, the debugger stops when it has reached the end of the code, or a breakpoint.

# %% [markdown]
# ## Question 11
# **What is the concept of a breakpoint?**

# %% [markdown]
# **Answer:**
#
# Breakpoint is what pauses the debugger when it reaches the line containing the breakpoint.
