# %% [markdown]
# # Assignment 18
#
# ***Name: Sushrut Gaikwad***

# %% [markdown]
# ## Question 1
# **Create a *zoo.py* file first. Define the `hours()` function, which prints the string `'Open 9-5 daily'`. Then, use the interactive interpreter to import the `zoo` module and call its `hours()` function.**

# %% [markdown]
# **Answer:**
#
# This is what is inside the *zoo.py* file.
# ```
# def hours():
#     print('Open 9-5 daily')
# ```

# %%
import zoo

zoo.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ## Question 2
# **In the interactive interpreter, import the `zoo` module as `menagerie` and call its `hours()` function.**

# %% [markdown]
# **Answer:**

# %%
import zoo as menagerie

menagerie.hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ## Question 3
# **Using the interpreter, explicitly import and call the `hours()` function from `zoo`.**

# %% [markdown]
# **Answer:**

# %%
from zoo import hours

hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# ## Question 4
# **Import the `hours()` function as `info` and call it.**

# %% [markdown]
# **Answer:**

# %%
from zoo import hours as info

info()
# Out:
# Open 9-5 daily

# %% [markdown]
# ## Question 5
# **Create a `plain` dictionary with the key-value pairs `'a': 1`, `'b': 2`, and `'c': 3`, and print it out.**

# %%
plain = {
    'a': 1,
    'b': 2,
    'c': 3
}

print(plain)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ## Question 6
# **Make an `OrderedDict` called `fancy` from the same pairs listed in question 5 and print it. Did it print in the same order as `plain`?**

# %% [markdown]
# **Answer:**

# %%
from collections import OrderedDict
fancy = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
print(fancy)
# Out:
# OrderedDict([('a', 1), ('b', 2), ('c', 3)])

# %% [markdown]
# ## Question 7
# **Make a `defaultdict` called `dict_of_lists` and pass it the argument `list`. Make the list `dict_of_lists['a']` and append the value `'something for a'` to it in one assignment. Print `dict_of_lists['a']`.**

# %% [markdown]
# **Answer:**

# %%
from collections import defaultdict
dict_of_lists = defaultdict(list)
dict_of_lists['a'].append('something for a')
print(dict_of_lists['a'])
# Out:
# ['something for a']
